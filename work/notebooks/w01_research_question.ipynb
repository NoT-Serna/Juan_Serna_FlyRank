# %% [markdown]
# <a href="https://colab.research.google.com/github/NoT-Serna/Juan_Serna_FlyRank/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# *The lane im choosing is Lane 4: CTR/Engagement Opportunity Scoring. I choose this lane because most of online businesses, content ceators and other types of digital entrepreneurships rely on the engagement and clicks to have their business relevant in the digital realm, so optimizing these factors and understanding the underlying data behind the variables can save and enhance a business.*

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# *My work imprvoes the decision on how to act on marekting and UX/UI teams. The people responsible for these departments would act on the analysis of the results of the model and therefore have metrcis on which to see if certain marketing or design featrues improve or worsen the underlying metrics of the site. The cost of a wrong recommendation would be to lose client engagement and possibly affect income and reputation of the business.*

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import os, sys, subprocess

IN_COLAB = "google.colab" in sys.modules
REPO_URL = "https://github.com/flyrank-bih/flyrank-ml-internship-starter"
REPO_DIR = "flyrank-ml-internship-starter"

if IN_COLAB:
    if not os.path.isdir(REPO_DIR):
        subprocess.run(["git", "clone", "--depth", "1", REPO_URL, REPO_DIR], check=True)
    os.chdir(REPO_DIR)
    subprocess.run([sys.executable, "-m", "pip", "install", "-q", "-r", "requirements.txt"], check=True)
elif os.path.basename(os.getcwd()) == "notebooks":
    os.chdir("..")  # move from notebooks/ to the repo root

print("Working dir:", os.getcwd())
assert os.path.exists("data/raw/content_refresh_anonymized.csv"), "starter CSV not found — are you at the repo root?"
print("Starter data found. You're ready.")
# Out:
# Working dir: /content/flyrank-ml-internship-starter
# Starter data found. You're ready.

# %%
# Watch it work — each of the 5 steps prints live as it runs (~1 minute total).
# !{sys.executable} scripts/run_all.py
# Out:
# ...
# ▶ Step 1/5 — Prepare features — clean the data, build the feature vector, define the label
# ...
# Prepared 30,000 rows from 30,000 raw rows
# Wrote /content/flyrank-ml-internship-starter/data/processed/refresh_feature_vector.csv
#
# ...
# ▶ Step 2/5 — Baseline — a transparent hand-written rule to beat
# ...
# Wrote baseline queue: /content/flyrank-ml-internship-starter/data/processed/baseline_refresh_queue.csv
# Top-50 declining rate (full data, not the evaluated holdout Precision@50): 0.340
#
# ...
# ▶ Step 3/5 — Train — logistic regression, decision tree, random forest (client-holdout split)
# ...
# Trained 3 models on 30,000 rows
# Split strategy: client_holdout
# Best model: random_forest
# Wrote predictions: /content/flyrank-ml-internship-starter/data/processed/model_predictions.csv
# Wrote model results: /content/flyrank-ml-internship-starter/outputs/model_results.json
#
# ...
# ▶ Step 4/5 — Evaluate — ranked refresh queue, charts, and the Markdown report
# ...

# %%
#Average Engagement Rate:
import pandas as pd
df = pd.read_csv("data/raw/content_refresh_anonymized.csv")
average_engagement= df['engagement_rate'].mean()
print(f"Average Engagement Rate: {average_engagement:.4f} \n")

print(df["engagement_rate"].head(10))
print(df["engagement_rate"].describe())
print(df["engagement_rate"].dtype)
# Out:
# Average Engagement Rate: 2.5345
#
# 0    5.88
# 1    0.00
# 2    0.00
# 3    1.28
# 4    0.00
# 5    0.00
# 6    0.00
# 7    3.57
# 8    5.88
# 9    0.00
# Name: engagement_rate, dtype: float64
# count    30000.000000
# mean         2.534520
# std          8.310096
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          1.350000
# max        100.000000
# Name: engagement_rate, dtype: float64
# float64

# %% [markdown]
# *These numbers tells us that at least 50% of all pages have an engagement rate of 0%, only the top 25% pages have an engagement rate above 1.35%. Data distribution is skewed*

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# *My work will be able to identify what pages based on their intention could get a better engagement, see if impresions are corelated with CTR or see if the age and freshness is associated in the inital engagement of a page. With my work I couldnt claim exact impresions, determine an exact range of engagement of a page nor predict clicks or CTR.*

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
